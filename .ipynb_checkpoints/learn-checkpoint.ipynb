# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# Numbers
age = 18
price = 19.99

# Text (Strings)
name = "Abhishek"
message = 'Hello'

# Boolean (True/False)
is_student = True
is_working = False

# Print variables
print(name)
print(age)
print(is_working)
print(price)
# Out:
# Abhishek
# 18
# False
# 19.99

# %%
name = input("What is your name? ")
print("Hello, " + name + "!")

age = input("How old are you? ")
print("You are " + age + " years old")
# Out:
# What is your name?  Abhishek Babu
# Hello, Abhishek Babu!
# How old are you?  18
# You are 18 years old

# %%
# Addition
print(5 + 3)  # 8

# Subtraction
print(10 - 4)  # 6

# Multiplication
print(3 * 4)  # 12

# Division
print(15 / 3)  # 5.0

# Simple calculator
x = 10
y = 5
print("Sum:", x + y)
print("Difference:", x - y)
print("Product:", x * y)
# Out:
# 8
# 6
# 12
# 5.0
# Sum: 15
# Difference: 5
# Product: 50
